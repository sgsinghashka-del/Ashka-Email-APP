# %% [markdown]
# <a href="https://colab.research.google.com/github/sgsinghashka-del/Ashka-Email-APP/blob/main/Email_Appipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
+%pip install -q --no-cache-dir \
    "google-auth==2.49.0" \
    "google-genai==2.12.0"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.4 MB/s eta 0:00:00

# %%
# Import the required libraries
from google import genai
from getpass import getpass


# Enter the Gemini API key securely
api_key = getpass("Enter your Gemini API key: ")


# Connect Python with Gemini
client = genai.Client(api_key=api_key)


# Take email input from the user
email_text = input("\nEnter your email:\n")


# Create a prompt for Gemini
prompt = f"""
Improve the following email.

Instructions:
- Correct grammar and spelling.
- Improve sentence structure.
- Make the email clear and professional.
- Keep the original meaning.
- Return only the improved email.

Email:
{email_text}
"""


# Send the prompt to Gemini
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt
)


# Display the improved email
print("\nImproved Email:\n")
print(response.text)
# Out:
# Enter your Gemini API key: ··········
#
# Enter your email:
# Email for Promotion for Redmi 14 Pro
#
# Improved Email:
#
# Subject: Introducing the All-New Redmi 14 Pro – Power, Performance, and Style
#
# Dear [Customer Name],
#
# Upgrade your mobile experience with the new Redmi 14 Pro! Designed to deliver exceptional performance, a sleek look, and cutting-edge features, it is everything you need in a smartphone.
#
# Key Features:
# • Stunning Display: Enjoy vibrant visuals on an ultra-smooth display.
# • Advanced Camera System: Capture every detail with high-resolution AI camera technology.
# • All-Day Battery Life: Stay connected longer with fast-charging support.
# • Powerful Performance: Experience seamless multitasking with the latest processor.
#
# Exclusive Launch Offer:
# Order today to take advantage of our special introductory price and receive [Insert Offer, e.g., 10% off / a free gift with purchase]!
#
# [Shop Now]
#
# ...

# %%
# Import the required libraries
from google import genai
from getpass import getpass


# Enter the Gemini API key securely
api_key = getpass("Enter your Gemini API key: ")


# Connect Python with Gemini
client = genai.Client(api_key=api_key)


# Take email input from the user
email_text = input("\nEnter your email:\n")


# Create a prompt for Gemini
prompt = f"""
Improve the following email.

Instructions:
- Correct grammar and spelling.
- Improve sentence structure.
- Make the email clear and professional.
- Keep the original meaning.
- Return only the improved email.
- Manager Name : Armaan
- My name is : Krish

Email:
{email_text}
"""


# Send the prompt to Gemini
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt
)


# Display the improved email
print("\nImproved Email:\n")
print(response.text)
# Out:
# Enter your Gemini API key: ··········
#
# Enter your email:
# Leave email for 2 days
#
# Improved Email:
#
# Subject: Request for Leave of Absence - 2 Days
#
# Dear Armaan,
#
# I am writing to formally request a two-day leave of absence from [Start Date] to [End Date].
#
# Before my leave, I will ensure that all my current tasks are up to date and delegate any urgent matters to [Colleague's Name / the team] to ensure a smooth workflow in my absence. I will also have limited access to my emails for any urgent issues.
#
# Thank you for considering my request. Please let me know if you need any additional details.
#
# Best regards,
#
# Krish

# %%
name = "Armaan"
result = f"Hello How are you? {name}"
print(result)
# Out:
# Hello How are you? Armaan

# %%
from google import genai
from getpass import getpass

# Enter the Gemini API key
api_key = getpass("Enter your Gemini API key: ")

# Connect Python with Gemini
client = genai.Client(api_key=api_key)

# Take booking details from the user
guest_name = input("Enter guest name: ")
check_in = input("Enter check-in date: ")
check_out = input("Enter check-out date: ")
number_of_guests = input("Enter number of guests: ")
room_type = input(
    "Enter room type (Deluxe, Premium or Family): "
)
special_request = input(
    "Enter special request or write None: "
)

# Create the prompt
prompt = f"""
You are a hotel booking assistant for Sunrise Stay Hotel, Delhi.

Prepare a clear and professional booking request response.

Booking Details:
Guest Name: {guest_name}
Check-in Date: {check_in}
Check-out Date: {check_out}
Number of Guests: {number_of_guests}
Room Type: {room_type}
Special Request: {special_request}

Instructions:
- Begin with a polite greeting.
- Mention all booking details correctly.
- Use clear and professional language.
- Mention the special request.
- Do not say that the booking is confirmed.
- Mention that the booking is subject to room availability.
- Return only the booking response.
- Don't use '**' in the response.
"""

# Send the prompt to Gemini
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt
)

# Display the generated response
print("\nHotel Booking Response:\n")
print(response.text)
# Out:
# Enter your Gemini API key: ··········
# Enter guest name: Krish
# Enter check-in date: 04 Aug 2026
# Enter check-out date: 05 Aug 2026
# Enter number of guests: 5
# Enter room type (Deluxe, Premium or Family): Deluxe
# Enter special request or write None: None
#
# Hotel Booking Response:
#
# Dear Krish,
#
# Greetings from Sunrise Stay Hotel, Delhi.
#
# Thank you for submitting your booking request with us. Please be advised that your reservation request is currently under review and is subject to room availability. Kindly note that this email is an acknowledgment of your request and not a confirmation of your booking.
#
# Here are the details of your booking request:
#
# Guest Name: Krish
# Check-in Date: 04 Aug 2026
# Check-out Date: 05 Aug 2026
# Number of Guests: 5
# Room Type: Deluxe
# Special Request: None
#
# ...
